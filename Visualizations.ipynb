# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Insert, change the directory 
import sys
sys.path.insert(0,'/content/drive/MyDrive/graph-based-fraud-detection-main')
# %cd /content/drive/MyDrive/graph-based-fraud-detection-main
# %cd /content/drive/MyDrive/dgl_fraud_detection
# Out:
# /content/drive/MyDrive/graph-based-fraud-detection-main

# %%
results = pd.read_csv('./output/results.txt')
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Epoch    1100 non-null   int64
#  1   Time(s)  1100 non-null   float64
#  2   Loss     1100 non-null   float64
#  3   F1       1100 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 34.5 KB

# %%
results.columns
# Out:
# Index(['Epoch', 'Time(s)', 'Loss', 'F1'], dtype='object')

# %%
results.iloc[:,0]
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#        ...
# 1095    995
# 1096    996
# 1097    997
# 1098    998
# 1099    999
# Name: Epoch, Length: 1100, dtype: int64

# %%
# plt.plot(results['Epoch'],results['Loss'])
plt.plot(results.iloc[:,0],results.iloc[:,2])
plt.xlabel('Epoch')        
plt.ylabel('Loss')   
plt.savefig('./output/loss.jpg')
plt.show()

# %%
# plt.plot(results['Epoch'],results['F1'])
plt.plot(results.iloc[:,0],results.iloc[:,3])
plt.xlabel('Epoch')        
plt.ylabel('F1 score')   
plt.savefig('./output/f1.jpg')
plt.show()

# %%
# total_min = np.sum(results['Time(s)']) / 60
total_min = np.sum(results.iloc[:,2]) / 60
print('Time cost:', round(total_min,2), 'minutes.')
# Out:
# Time cost: 5.72 minutes.

# %%
# y-axis in log scale

plt.plot(results['Epoch'],results['Loss'])
plt.yscale('log')
plt.xlabel('Epoch')        
plt.ylabel('Loss')   
plt.show()
